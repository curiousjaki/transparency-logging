# %%
import json
import xmltodict

discovered_dict = {}
with open("output.bpmn") as discovered_bpmn:
    discovered_dict = xmltodict.parse(discovered_bpmn.read())

# %%
discovered_dict
# Out:
# {'bpmn:definitions': {'@xmlns:bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL',
#   '@xmlns:bpmndi': 'http://www.omg.org/spec/BPMN/20100524/DI',
#   '@xmlns:omgdc': 'http://www.omg.org/spec/DD/20100524/DC',
#   '@xmlns:omgdi': 'http://www.omg.org/spec/DD/20100524/DI',
#   '@xmlns:tilt': 'mytilturi.com',
#   '@xmlns:bioc': 'http://bpmn.io/schema/bpmn/biocolor/1.0',
#   '@xmlns:color': 'http://www.omg.org/spec/BPMN/non-normative/color/1.0',
#   '@targetNamespace': 'http://www.signavio.com/bpmn20',
#   '@exporter': 'Camunda Modeler',
#   '@exporterVersion': '5.6.0',
#   'bpmn:process': {'@id': 'id212733dc-53b0-408e-a05d-bac3c8f33f49',
#    '@processType': 'None',
#    '@isClosed': 'false',
#    '@isExecutable': 'false',
#    'bpmn:task': [{'@id': 'id939798b7-98c9-444e-befc-ba6ab308bf07',
#      '@name': 'Combine User Data',
#      'bpmn:extensionElements': {'tilt:dataDisclosed': [{'@_id': '-2402903000197690004',
#         '@category': 'address',
# ...
